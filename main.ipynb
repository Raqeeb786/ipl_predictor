# %% [markdown]
# <h1>IPL DATA ANALYSIS</h1>

# %% [markdown]
# This python file deals with analysis of data and prediction of the team.

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading file

# %%
df = pd.read_csv("data/cricket_data_2025.csv")

# %%
df.head()
# Out:
#      Year   Player_Name Matches_Batted  Not_Outs Runs_Scored Highest_Score  \
# 0     NaN  Aaron Hardie       No stats  No stats    No stats      No stats
# 1  2024.0   Abdul Samad             16         2         182           37*
# 2  2023.0   Abdul Samad              9         4         169           37*
# 3  2022.0   Abdul Samad              2         0           4             4
# 4  2021.0   Abdul Samad             11         1         111            28
#
#   Batting_Average Balls_Faced Batting_Strike_Rate Centuries  ...  \
# 0        No stats    No stats            No stats  No stats  ...
# 1            18.2         108              168.52         0  ...
# 2           42.25         128              132.03         0  ...
# 3             2.0           7               57.14         0  ...
# 4           12.33          87              127.58         0  ...
#
#   Matches_Bowled Balls_Bowled Runs_Conceded Wickets_Taken Best_Bowling_Match  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 957 non-null    float64
#  1   Player_Name          1008 non-null   object
#  2   Matches_Batted       1008 non-null   object
#  3   Not_Outs             1008 non-null   object
#  4   Runs_Scored          1008 non-null   object
#  5   Highest_Score        1008 non-null   object
#  6   Batting_Average      1008 non-null   object
#  7   Balls_Faced          1008 non-null   object
#  8   Batting_Strike_Rate  1008 non-null   object
#  9   Centuries            1008 non-null   object
#  10  Half_Centuries       1008 non-null   object
#  11  Fours                1008 non-null   object
#  12  Sixes                1008 non-null   object
#  13  Catches_Taken        1008 non-null   object
#  14  Stumpings            1008 non-null   object
# ...

# %%
for i in df.columns:
    print(i)
    print(df[i].unique())
    print("***************")
# Out:
# Year
# [  nan 2024. 2023. 2022. 2021. 2020. 2019. 2018. 2017. 2016. 2015. 2014.
#  2013. 2012. 2011. 2009. 2008. 2010.]
# ***************
# Player_Name
# ['Aaron Hardie' 'Abdul Samad' 'Abhinandan Singh' 'Abhinav Manohar'
#  'Abhishek Sharma' 'Abishek Porel' 'Adam Zampa' 'Aiden Markram'
#  'Ajay Mandal' 'Ajinkya Rahane' 'Akash Deep' 'Akash Madhwal' 'Akash Singh'
#  'Andre Russell' 'Andre Siddarth' 'Angkrish Raghuvanshi' 'Aniket Verma'
#  'Anrich Nortje' 'Anshul Kamboj' 'Anuj Rawat' 'Anukul Roy'
#  'Arjun Tendulkar' 'Arshdeep Singh' 'Arshin Kulkarni' 'Aryan Juyal'
#  'Ashok Sharma' 'Ashutosh Sharma' 'Ashwani Kumar' 'Atharva Taide'
#  'Avesh Khan' 'Axar Patel' 'Ayush Badoni' 'Azmatullah Omarzai'
#  'B. Sai Sudharsan' 'Bevon-John Jacobs' 'Bhuvneshwar Kumar' 'Corbin Bosch'
#  'Darshan Nalkande' 'David Miller' 'Deepak Chahar' 'Deepak Hooda'
#  'Devdutt Padikkal' 'Devon Conway' 'Dhruv Jurel' 'Digvesh Singh'
#  'Donovan Ferreira' 'Dushmantha Chameera' 'Eshan Malinga' 'Faf du Plessis'
# ...

# %%
df[['Player_Name','Batting_Average']].sort_values(by='Batting_Average',ascending=False).head(10)
# Out:
#          Player_Name  Batting_Average
# 164     Deepak Hooda           101.00
# 468    Manish Pandey            84.00
# 429         MS Dhoni            83.20
# 956      Virat Kohli            81.08
# 430         MS Dhoni            75.83
# 697  Ravindra Jadeja            75.66
# 434         MS Dhoni            74.20
# 141     David Miller            68.71
# 16   Abhishek Sharma            63.00
# 333         KL Rahul            62.60
